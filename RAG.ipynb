# %%
from dotenv import load_dotenv
load_dotenv()

from ingest import load_faq_data, build_index
from rag_helper import RAGBase
from openai import OpenAI

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
client = OpenAI()

# %%
assistant = RAGBase(
    index=index,
    llm_client=client,
)

# %%
questions = [
    "I just discovered the course. Can I join now?",
    "Do I need to join a live cohort in order to take the course?",
    "What are the requirements to get a certificate?",
]

# %%
for question in questions:
    answer = assistant.rag(question)
    print(f"Q: {question}")
    print(f"A: {answer}")
    print()
# Out:
# Q: I just discovered the course. Can I join now?
# A: Yes, but if you want to receive a certificate, you need to submit your project while the course is still accepting submissions.
#
# Q: Do I need to join a live cohort in order to take the course?
# A: Yes — if you want to get a certificate, you need to take the course with a live cohort. Self-paced participation is allowed, but certificates are only awarded for the live cohort.
#
# Q: What are the requirements to get a certificate?
# A: To get a certificate, you need to finish the course with a live cohort and pass the Capstone project. You also need to peer-review 3 capstone projects after submitting your own project. Homework is not mandatory for the certificate.
